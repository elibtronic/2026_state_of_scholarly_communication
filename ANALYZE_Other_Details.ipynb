# %% [markdown]
# # Other fun details
#
# This notebook will generate addtional info that is included at the end of the report

# %%
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pickle

# %%
pd.set_option('display.max_columns', None)
colors = sns.color_palette('inferno_r')
color = sns.color_palette('inferno_r')[0]

#Total works from OpenAlex
WORKS_PICKLE = "2026_API_GRAB.pkl"

#Post Handcheck CSV
FINAL_TITLES = "2026_Papers_to_Check.csv"

#Multi year spreadsheet
LONG_DATA = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQzygCvwtLMntovyqRVjgZUmRPrl4Buo8j9x2j9XecRrSGM7erBu3003UfZenbdwkOjEPgeozJ7ZRbf/pub?output=csv"

# %% [markdown]
# ## For this year

# %%
#top 10 sources

# %%
#top 10 publisher

# %%
#open versus closed for top 10

# %%
#international colaborations

# %% [markdown]
# ## Comparing for all data

# %%
# total  open/closed for 2025 and 2026
